# %%
import pandas as pd
df = pd.read_pickle("models/sciq_processed.pkl")

# %%
from preprocessing import preprocess

# %%
from models.grading_model import GradingModel
grader = GradingModel()
# Out:
# Grading Model Loaded Successfully!

# %%
grader.grade(
    question_id=8,
    student_answer="Radiation",
    preprocess_fn=preprocess
)
# Out:
# {'question_id': 8,
#  'cleaned_answer': 'radiation',
#  'marks': 8,
#  'similarity_score': 0.6716548204421997,
#  'correct_key_answer': 'radioactivity'}
